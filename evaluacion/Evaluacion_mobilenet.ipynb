# %% [markdown]
# #**Evaluación Del Modelo MOBILENET V2**

# %% [markdown]
# ### *Librerías Necesarias*

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %% [markdown]
# ### *Se leen las dos Lista a comparar (Real y Predicha)*

# %%
y_true=pd.read_csv("list_test.csv",sep=",")
y_pred3=pd.read_csv("list_predict_mobi.csv",sep=",")

# %% [markdown]
# ### *Se genera la Matriz de Confusión*

# %%
cm3=confusion_matrix(y_true,y_pred3)
print(cm3)
# Out:
# [[26 24]
#  [ 7 43]]

# %%
col=["0","1"]
df_cm3=pd.DataFrame(cm3, index=col, columns=col)
grafica=sns.heatmap(cm3, annot=True)
grafica.set(xlabel="Predicciones", ylabel="Verdaderos", title="MOBILENET - RESIZE")
plt.show()

# %% [markdown]
# ### *Se calculan las Métricas de Evaluación*

# %%
metricas3=classification_report(y_true, y_pred3)
print(metricas3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.52      0.63        50
#            1       0.64      0.86      0.74        50
#
#     accuracy                           0.69       100
#    macro avg       0.71      0.69      0.68       100
# weighted avg       0.71      0.69      0.68       100
